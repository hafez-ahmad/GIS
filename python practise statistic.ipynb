# %%
import pandas as pd 
from pandas import Series, DataFrame
import numpy as np

# %%
df1=pd.read_csv("bond_sci_water_live.csv")

# %%
df1
# Out:
#           unixtime        lat        lon      depth  sci_m_present_time  \
# 0     1.505146e+09  44.388283 -63.360458   0.000000        1.505146e+09
# 1     1.505146e+09  44.388212 -63.360468   0.558771        1.505146e+09
# 2     1.505146e+09  44.388157 -63.360452   8.841177        1.505146e+09
# 3     1.505146e+09  44.388107 -63.360283  19.314221        1.505146e+09
# 4     1.505146e+09  44.388056 -63.360113  26.794932        1.505146e+09
# 5     1.505146e+09  44.388006 -63.359944  35.246340        1.505146e+09
# 6     1.505146e+09  44.387955 -63.359775  43.456087        1.505146e+09
# 7     1.505146e+09  44.387905 -63.359605  50.892449        1.505146e+09
# 8     1.505147e+09  44.387854 -63.359436  58.211786        1.505147e+09
# 9     1.505147e+09  44.387804 -63.359267  65.482758        1.505147e+09
# 10    1.505147e+09  44.387753 -63.359098  73.453424        1.505147e+09
# 11    1.505147e+09  44.387703 -63.358928  81.091962        1.505147e+09
# ...

# %%
import matplotlib.pyplot as plt

# %%
matplotlib.style.use('ggplot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ec02f630f9dc> in <module>()
# ----> 1 matplotlib.style.use('ggplot')
#
# NameError: name 'matplotlib' is not defined

# %%
import matplotlib

# %%
matplotlib.style.use('ggplot')

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
from numpy.random import randn

# %%
from scipy import stats

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1=pd.read_csv("bond_sci_water_live.csv")

# %%
df1
# Out:
#           unixtime        lat        lon      depth  sci_m_present_time  \
# 0     1.505146e+09  44.388283 -63.360458   0.000000        1.505146e+09
# 1     1.505146e+09  44.388212 -63.360468   0.558771        1.505146e+09
# 2     1.505146e+09  44.388157 -63.360452   8.841177        1.505146e+09
# 3     1.505146e+09  44.388107 -63.360283  19.314221        1.505146e+09
# 4     1.505146e+09  44.388056 -63.360113  26.794932        1.505146e+09
# 5     1.505146e+09  44.388006 -63.359944  35.246340        1.505146e+09
# 6     1.505146e+09  44.387955 -63.359775  43.456087        1.505146e+09
# 7     1.505146e+09  44.387905 -63.359605  50.892449        1.505146e+09
# 8     1.505147e+09  44.387854 -63.359436  58.211786        1.505147e+09
# 9     1.505147e+09  44.387804 -63.359267  65.482758        1.505147e+09
# 10    1.505147e+09  44.387753 -63.359098  73.453424        1.505147e+09
# 11    1.505147e+09  44.387703 -63.358928  81.091962        1.505147e+09
# ...

# %%
dataset1=randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  4.,   5.,  16.,  19.,  28.,   6.,  11.,   6.,   3.,   2.]),
#  array([-2.05270747, -1.57824011, -1.10377275, -0.62930539, -0.15483803,
#          0.31962933,  0.79409669,  1.26856405,  1.74303141,  2.21749877,
#          2.69196613]),
#  <a list of 10 Patch objects>)

# %%
dataset2=randn(80)
plt.hist(dataset2,color='indianred')
# Out:
# (array([  4.,  11.,   7.,  12.,  15.,  15.,   6.,   4.,   4.,   2.]),
#  array([-1.59182095, -1.18532393, -0.77882691, -0.37232989,  0.03416713,
#          0.44066414,  0.84716116,  1.25365818,  1.6601552 ,  2.06665222,
#          2.47314924]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True ,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.5,bins=20)
# Out:
# (array([ 0.1845032 ,  0.06150107,  0.1845032 ,  0.49200853,  0.24600426,
#          0.1845032 ,  0.30750533,  0.43050746,  0.3690064 ,  0.55350959,
#          0.67651173,  0.24600426,  0.12300213,  0.24600426,  0.12300213,
#          0.12300213,  0.12300213,  0.12300213,  0.06150107,  0.06150107]),
#  array([-1.59182095, -1.38857244, -1.18532393, -0.98207542, -0.77882691,
#         -0.5755784 , -0.37232989, -0.16908138,  0.03416713,  0.23741563,
#          0.44066414,  0.64391265,  0.84716116,  1.05040967,  1.25365818,
#          1.45690669,  1.6601552 ,  1.86340371,  2.06665222,  2.26990073,
#          2.47314924]),
#  <a list of 20 Patch objects>)

# %%
data1=randn(1000)
data2=randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')

# %%
data2=randn(10000)

# %%
plt.hist(data2,color='green')
# Out:
# (array([   21.,   158.,   649.,  1594.,  2563.,  2652.,  1602.,   607.,
#           138.,    16.]),
#  array([ -3.53646605e+00,  -2.82971628e+00,  -2.12296651e+00,
#          -1.41621674e+00,  -7.09466974e-01,  -2.71720466e-03,
#           7.04032565e-01,   1.41078233e+00,   2.11753210e+00,
#           2.82428187e+00,   3.53103164e+00]),
#  <a list of 10 Patch objects>)

# %%
df1=pd.read_csv('bond_sci_water_live.csv')
df1
# Out:
#           unixtime        lat        lon      depth  sci_m_present_time  \
# 0     1.505146e+09  44.388283 -63.360458   0.000000        1.505146e+09
# 1     1.505146e+09  44.388212 -63.360468   0.558771        1.505146e+09
# 2     1.505146e+09  44.388157 -63.360452   8.841177        1.505146e+09
# 3     1.505146e+09  44.388107 -63.360283  19.314221        1.505146e+09
# 4     1.505146e+09  44.388056 -63.360113  26.794932        1.505146e+09
# 5     1.505146e+09  44.388006 -63.359944  35.246340        1.505146e+09
# 6     1.505146e+09  44.387955 -63.359775  43.456087        1.505146e+09
# 7     1.505146e+09  44.387905 -63.359605  50.892449        1.505146e+09
# 8     1.505147e+09  44.387854 -63.359436  58.211786        1.505147e+09
# 9     1.505147e+09  44.387804 -63.359267  65.482758        1.505147e+09
# 10    1.505147e+09  44.387753 -63.359098  73.453424        1.505147e+09
# 11    1.505147e+09  44.387703 -63.358928  81.091962        1.505147e+09
# ...

# %% [markdown]
# df1

# %%
df1['sci_water_temp','sci_water_pressure']]
# Out:
#   File "<ipython-input-53-601f9e113fa4>", line 1
#     df1=['sci_water_temp','sci_water_pressure']]
#                                                ^
# SyntaxError: invalid syntax

# %%
'sci_water_temp'
# Out:
# 'sci_water_temp'

# %%
df1.cumsum
# Out:
# <bound method DataFrame.cumsum of           unixtime        lat        lon      depth  sci_m_present_time  \
# 0     1.505146e+09  44.388283 -63.360458   0.000000        1.505146e+09
# 1     1.505146e+09  44.388212 -63.360468   0.558771        1.505146e+09
# 2     1.505146e+09  44.388157 -63.360452   8.841177        1.505146e+09
# 3     1.505146e+09  44.388107 -63.360283  19.314221        1.505146e+09
# 4     1.505146e+09  44.388056 -63.360113  26.794932        1.505146e+09
# 5     1.505146e+09  44.388006 -63.359944  35.246340        1.505146e+09
# 6     1.505146e+09  44.387955 -63.359775  43.456087        1.505146e+09
# 7     1.505146e+09  44.387905 -63.359605  50.892449        1.505146e+09
# 8     1.505147e+09  44.387854 -63.359436  58.211786        1.505147e+09
# 9     1.505147e+09  44.387804 -63.359267  65.482758        1.505147e+09
# 10    1.505147e+09  44.387753 -63.359098  73.453424        1.505147e+09
# 11    1.505147e+09  44.387703 -63.358928  81.091962        1.505147e+09
# ...

# %%
df1.describe()
# Out:
#            unixtime          lat          lon        depth  \
# count  4.803000e+03  4803.000000  4803.000000  4803.000000
# mean   1.505307e+09    44.360544   -63.230101    57.116604
# std    9.268838e+04     0.047799     0.039734    39.271258
# min    1.505146e+09    44.299929   -63.360468     0.000000
# 25%    1.505226e+09    44.324856   -63.242755    23.874596
# 50%    1.505308e+09    44.345830   -63.215888    51.280964
# 75%    1.505388e+09    44.385437   -63.206150    85.246483
# max    1.505466e+09    44.478047   -63.180486   160.359156
#
#        sci_m_present_time  sci_water_cond  sci_water_pressure  sci_water_temp
# count        4.803000e+03     4803.000000         4803.000000     4803.000000
# mean         1.505307e+09        3.409632            5.647500        8.738730
# std          9.268838e+04        0.498249            3.918496        4.937597
# min          1.505146e+09        0.000000           -0.024000        0.000000
# ...

# %%
 from IPython.display import YouTubevideo
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-62-f0ca288d27a0> in <module>()
# ----> 1 from IPython.display import YouTubevideo
#
# ImportError: cannot import name YouTubevideo

# %%
df1=DataFrame(index=['data'])
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [data]

# %% [markdown]
# df1

# %%
df1=pd.read_csv('b1.csv')

# %%
df1
# Out:
#           unixtime        lat        lon      depth  sci_m_present_time  \
# 0     1.505146e+09  44.388283 -63.360458   0.000000        1.505146e+09
# 1     1.505146e+09  44.388212 -63.360468   0.558771        1.505146e+09
# 2     1.505146e+09  44.388157 -63.360452   8.841177        1.505146e+09
# 3     1.505146e+09  44.388107 -63.360283  19.314221        1.505146e+09
# 4     1.505146e+09  44.388056 -63.360113  26.794932        1.505146e+09
# 5     1.505146e+09  44.388006 -63.359944  35.246340        1.505146e+09
# 6     1.505146e+09  44.387955 -63.359775  43.456087        1.505146e+09
# 7     1.505146e+09  44.387905 -63.359605  50.892449        1.505146e+09
# 8     1.505147e+09  44.387854 -63.359436  58.211786        1.505147e+09
# 9     1.505147e+09  44.387804 -63.359267  65.482758        1.505147e+09
# 10    1.505147e+09  44.387753 -63.359098  73.453424        1.505147e+09
# 11    1.505147e+09  44.387703 -63.358928  81.091962        1.505147e+09
# ...

# %%
df1=DataFrame(index=['temp'])

# %%
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [temp]

# %%
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [temp]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from __future__ import division

# %%
import matplotlib.pyplot as plt
import requests

# %%
from StringIO import StringIO

# %%
url='http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.cvsmatplotlib-visualize-csv-data'
source=requests.get(url).text
poll_data=StringIO(source)

# %%
polld=pd.read_csv(poll_data)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-120-c5d0695c97ac> in <module>()
# ----> 1 polld=pd.read_csv(poll_data)
#
# C:\Anaconda\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
poll_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3008 entries,                 data-pqss-id="29761" data-choices="obama to </html>
# Data columns (total 1 columns):
#                 data-poll-id="14151" data-pollster-slug="rasmussen" data-end-date="2012-06-21" data-partisan="N"    349 non-null object
# dtypes: object(1)
# memory usage: 23.5+ KB

# %%
sns.factorplot('sci_water_temp',data=df1)

# %%
avg=pd.DataFrame(df1.mean())

# %%
avg.drop('sci_water_temp',axis=0,inplace=True)

# %%
avg.head()
# Out:
#                                0
# unixtime            1.505307e+09
# lat                 4.436054e+01
# lon                -6.323010e+01
# depth               5.711660e+01
# sci_m_present_time  1.505307e+09

# %%
std=pd.DataFrame(df1.std())
std.drop('sci_water_temp',axis=0,inplace=True)

# %%
std.head()
# Out:
#                                0
# unixtime            92688.383530
# lat                     0.047799
# lon                     0.039734
# depth                  39.271258
# sci_m_present_time  92688.383530

# %%
avg.plot(yerr=std,kind='bar',legend=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('ggplot')

# %%
x=np.linspace(-2*np.pi,2*np.pi ,endpoint=True)
y=np.sin(x)

# %%
plt.plot(x,y)
plt.xlabel('Angle [rad]')
plt.ylabel('sin(x)')
plt.title('sine graph')
plt.show()

# %%
import pandas
data =pandas.read_csv('brain_size.csv')
data
# Out:
#     Unnamed: 0    Gender  FSIQ  VIQ  PIQ Weight  Height  MRI_Count
# 0            1  "Female"   133  132  124  "118"  "64.5"     816932
# 1            2    "Male"   140  150  124    "."  "72.5"    1001121
# 2            3    "Male"   139  123  150  "143"  "73.3"    1038437
# 3            4    "Male"   133  129  128  "172"  "68.8"     965353
# 4            5  "Female"   137  132  134  "147"  "65.0"     951545
# 5            6  "Female"    99   90  110  "146"  "69.0"     928799
# 6            7  "Female"   138  136  131  "138"  "64.5"     991305
# 7            8  "Female"    92   90   98  "175"  "66.0"     854258
# 8            9    "Male"    89   93   84  "134"  "66.3"     904858
# 9           10    "Male"   133  114  147  "172"  "68.8"     955466
# 10          11  "Female"   132  129  124  "118"  "64.5"     833868
# 11          12    "Male"   141  150  128  "151"  "70.0"    1079549
# 12          13    "Male"   135  129  124  "155"  "69.0"     924059
# ...

# %%
data.head()
# Out:
#    Unnamed: 0    Gender  FSIQ  VIQ  PIQ Weight  Height  MRI_Count
# 0           1  "Female"   133  132  124  "118"  "64.5"     816932
# 1           2    "Male"   140  150  124    "."  "72.5"    1001121
# 2           3    "Male"   139  123  150  "143"  "73.3"    1038437
# 3           4    "Male"   133  129  128  "172"  "68.8"     965353
# 4           5  "Female"   137  132  134  "147"  "65.0"     951545

# %%
data.shape
# Out:
# (40, 8)

# %%
print(data['Gender'])
# Out:
# 0     "Female"
# 1       "Male"
# 2       "Male"
# 3       "Male"
# 4     "Female"
# 5     "Female"
# 6     "Female"
# 7     "Female"
# 8       "Male"
# 9       "Male"
# 10    "Female"
# 11      "Male"
# 12      "Male"
# 13    "Female"
# 14    "Female"
# 15    "Female"
# 16    "Female"
# 17      "Male"
# 18    "Female"
# 19      "Male"
# 20      "Male"
# 21      "Male"
# 22    "Female"
# 23      "Male"
# 24    "Female"
# 25      "Male"
# 26    "Female"
# 27      "Male"
# 28    "Female"
# 29    "Female"
# 30    "Female"
# 31      "Male"
# 32      "Male"
# 33      "Male"
# 34    "Female"
# 35    "Female"
# 36      "Male"
# 37    "Female"
# 38      "Male"
# 39      "Male"
# Name: Gender, dtype: object

# %%
from scipy import stats
stats.ttest_1samp(data['FSIQ'] - data['PIQ'], 0)
# Out:
# Ttest_1sampResult(statistic=1.7842019405859857, pvalue=0.082172638183642358)

# %%
stats.ttest_1samp(data['VIQ'], 0)
# Out:
# Ttest_1sampResult(statistic=30.088099970849328, pvalue=1.3289196468728067e-28)

# %%
print(data['VIQ'])
# Out:
# 0     132
# 1     150
# 2     123
# 3     129
# 4     132
# 5      90
# 6     136
# 7      90
# 8      93
# 9     114
# 10    129
# 11    150
# 12    129
# 13    120
# 14    100
# 15     71
# 16    132
# 17     96
# 18    112
# 19     77
# 20     83
# 21    107
# 22    129
# 23    145
# 24     86
# 25    145
# 26     90
# 27     96
# 28     83
# 29    126
# 30    126
# 31    145
# 32     96
# 33     96
# 34     90
# 35    129
# 36    150
# 37     86
# 38     90
# 39     91
# Name: VIQ, dtype: int64

# %%
import seaborn as sb

# %%
import pandas as pd
flw=pd.read_csv('GroupA.csv')
flw.head(2)
# Out:
#    no.  Unnamed: 1            species   length (cm)  weight (gm)     log_l  \
# 0    1         NaN  thryssa hamiltonii         13.2         14.2  1.120574
# 1    2         NaN  thryssa hamiltonii         12.4         11.5  1.093422
#
#       log_w  condition factor  Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0  1.152288           0.61740         NaN        NaN         NaN         NaN
# 1  1.060698           0.60316         NaN        NaN         NaN         NaN
#
#   Unnamed: 12
# 0         NaN
# 1         NaN

# %%
sb.pairplot(flw, vars=['log_l', 'log_w'],hue='species')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-eb31fc2a0467> in <module>()
#       1
# ----> 2 sb.pairplot(flw, vars=['log_l', 'log_w'],hue='species')
#
# C:\anaconda\lib\site-packages\seaborn\linearmodels.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1588                     hue_order=hue_order, palette=palette,
#    1589                     diag_sharey=diag_sharey,
# -> 1590                     size=size, aspect=aspect, dropna=dropna, **grid_kws)
#    1591
#    1592     # Add the markers here as PairGrid has figured out how many levels of the
#
# C:\anaconda\lib\site-packages\seaborn\axisgrid.pyc in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, size, aspect, despine, dropna)
# ...

# %%
plt.title('length and weight relationship of fish')
plt.show()

# %%
sb.pairplot(data, vars=['VIQ', 'FSIQ', 'PIQ'],kind='Weight',hue='Gender')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5747344d270c> in <module>()
# ----> 1 sb.pairplot(data, vars=['VIQ', 'FSIQ', 'PIQ'],kind='Weight',hue='Gender')
#
# NameError: name 'data' is not defined

# %%
plt.show()

# %%
import

# %%
sb.pairplot(data, vars=['VIQ', 'FSIQ', 'PIQ'])
plt.show()

# %%
iris = sb.load_dataset("iris")
g = sb.pairplot(iris)

# %%
plt.show()

# %%
g = sb.pairplot(iris, hue="species")

# %%
plt.show()

# %%
sb.pairplot(iris,kind='reg')

# %%
plt.show()

# %%
import seaborn as sns
sns.set()

# Load the example tips dataset

iris=sns.load_dataset("iris")
# Plot tip as a function of toal bill across days
g = sns.lmplot(x="sepal_length", y="petal_length", hue="species",
               truncate=True, size=5, data=iris)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Sepal length (mm)", "petal length(mm)")

# %%
plt.show()

# %%
import pandas as pd
iris=pd.read_csv('iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width       name
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    name
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.plot(iris['sepal_length'])

# %%
plt.plot(iris['petal_width'])

# %%
plt.legend()
plt.show()

# %%
sns.set(style="darkgrid")
iris = sns.load_dataset("iris")

# Subset the iris dataset by species
setosa = iris.query("species == 'setosa'")
virginica = iris.query("species == 'virginica'")
versicolor=iris.query("species=='versicolor'")

# Set up the figure
f, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")

# Draw the two density plots
ax = sns.kdeplot(setosa.sepal_width, setosa.sepal_length,
                 cmap="Reds", shade=True, shade_lowest=False)
ax = sns.kdeplot(virginica.sepal_width, virginica.sepal_length,
                 cmap="Blues", shade=True, shade_lowest=False)
ax = sns.kdeplot(versicolor.sepal_width, versicolor.sepal_length,
                 cmap="Greens", shade=True, shade_lowest=False)

# Add labels to the plot
red = sns.color_palette("Reds")[-2]
blue = sns.color_palette("Blues")[-2]
green=sns.color_palette("Greens")[-2]
ax.text(2.5, 8.2, "virginica", size=16, color=blue)
ax.text(3.8, 4.5, "setosa", size=16, color=red)
ax.text(5.1,7.4,"versicolor",size=16,color=green)

# %%
plt.show()

# %%
plt.show()

# %%
sns.set(style="white")

df = sns.load_dataset("iris")

g = sns.PairGrid(df, diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Greens_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot, lw=3)

# %%
plt.show()

# %%
url='https://pkgstore.datahub.io/core/global-temp/1/monthly_csv/data/329e553af20ec84034a29372c0dce362/monthly_csv.csv'

# %%
temp=pd.read_clipboard()

# %%
temp.head()
# Out:
#           Source,Date,Mean
# 0   GCAG,2016-12-08,0.7895
# 1  GISTEMP,2016-12-08,0.81
# 2   GCAG,2016-11-08,0.7504
# 3  GISTEMP,2016-11-08,0.93
# 4   GCAG,2016-10-08,0.7292

# %%
temp=pd.read_excel('global_temperature.xlsx')

# %%
temp.head()
# Out:
#     Source       Date    Mean
# 0     GCAG 2016-12-08  0.7895
# 1  GISTEMP 2016-12-08  0.8100
# 2     GCAG 2016-11-08  0.7504
# 3  GISTEMP 2016-11-08  0.9300
# 4     GCAG 2016-10-08  0.7292

# %%
plt.plot(temp['Mean'])

# %%
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import netCDF4

# %%
plt.figure()

# %%
url='http://nomads.ncep.noaa.gov:9090/dods/rtofs/rtofs_global20171110'

# %%
f = netCDF4.Dataset('rtofs_glo_3dz_f006_6hrly_reg3.nc')
print(f)
# Out:
# <type 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     Conventions: CF-1.0
#     title: HYCOM ATLb2.00
#     institution: National Centers for Environmental Prediction
#     source: HYCOM archive file
#     experiment: 90.9
#     history: archv2ncdf3z
#     dimensions(sizes): MT(1), Y(850), X(712), Depth(10)
#     variables(dimensions): float64 MT(MT), float64 Date(MT), float32 Depth(Depth), int32 Y(Y), int32 X(X), float32 Latitude(Y,X), float32 Longitude(Y,X), float32 u(MT,Depth,Y,X), float32 v(MT,Depth,Y,X), float32 temperature(MT,Depth,Y,X), float32 salinity(MT,Depth,Y,X)
#     groups:

# %%
print(f.variables.keys()) # get all variable names
# Out:
# [u'MT', u'Date', u'Depth', u'Y', u'X', u'Latitude', u'Longitude', u'u', u'v', u'temperature', u'salinity']

# %%
temp = f.variables['temperature']  # temperature variable
print(temp)
# Out:
# <type 'netCDF4._netCDF4.Variable'>
# float32 temperature(MT, Depth, Y, X)
#     coordinates: Longitude Latitude Date
#     standard_name: sea_water_potential_temperature
#     units: degC
#     _FillValue: 1.26765e+30
#     valid_range: [ -5.07860279  11.14989948]
#     long_name:   temp [90.9H]
# unlimited dimensions: MT
# current shape = (1, 10, 850, 712)
# filling on

# %%
temp.dimensions
# Out:
# (u'MT', u'Depth', u'Y', u'X')

# %%
temp.shape
# Out:
# (1, 10, 850, 712)

# %%
mt = f.variables['MT']
depth = f.variables['Depth']
x,y = f.variables['X'], f.variables['Y']
print(mt)
print(x)
# Out:
# <type 'netCDF4._netCDF4.Variable'>
# float64 MT(MT)
#     long_name: time
#     units: days since 1900-12-31 00:00:00
#     calendar: standard
#     axis: T
# unlimited dimensions: MT
# current shape = (1,)
# filling on, default _FillValue of 9.96920996839e+36 used
#
# <type 'netCDF4._netCDF4.Variable'>
# int32 X(X)
#     point_spacing: even
#     axis: X
# unlimited dimensions:
# current shape = (712,)
# filling on, default _FillValue of -2147483647 used

# %%
lat, lon = f.variables['Latitude'], f.variables['Longitude']
print(lat)
# Out:
# <type 'netCDF4._netCDF4.Variable'>
# float32 Latitude(Y, X)
#     standard_name: latitude
#     units: degrees_north
# unlimited dimensions:
# current shape = (850, 712)
# filling on, default _FillValue of 9.96920996839e+36 used

# %%
sal = f.variables['salinity']

# %%
latvals = lat[:]; lonvals = lon[:]

# %%
def getclosest_ij(lats,lons,latpt,lonpt):
    # find squared distance of every point on grid
    dist_sq = (lats-latpt)**2 + (lons-lonpt)**2  
    # 1D index of minimum dist_sq element
    minindex_flattened = dist_sq.argmin()    
    # Get 2D index for latvals and lonvals arrays from 1D index
    return np.unravel_index(minindex_flattened, lats.shape)
iy_min, ix_min = getclosest_ij(latvals, lonvals, 50., -140)

# %%
sal = f.variables['salinity']
# Read values out of the netCDF file for temperature and salinity
print('%7.4f %s' % (temp[0,0,iy_min,ix_min], temp.units))
print('%7.4f %s' % (sal[0,0,iy_min,ix_min], sal.units))
# Out:
#  6.4631 degC
# 32.6572 psu

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot()
# Out:
# []

# %%
ts=np.random.randn(1000)

# %%
ts
# Out:
# array([  1.11760246e+00,   9.51710926e-01,  -2.16950394e+00,
#          1.99424483e+00,   7.39178604e-01,  -1.64046982e-01,
#         -7.53086902e-01,   1.56168860e+00,   3.85519247e-01,
#          2.65469712e-01,  -8.66664626e-01,  -4.70445236e-01,
#         -8.51720544e-01,  -6.23171421e-01,   2.63785290e+00,
#          5.38525388e-01,   8.43570567e-01,   1.22351475e+00,
#         -1.43511422e-01,  -3.53380521e+00,   1.21504509e+00,
#          1.90964030e-01,   2.91770992e-01,   2.90851469e-01,
#         -1.42363013e+00,   5.33824935e-01,  -1.95028258e+00,
#         -1.35612991e-01,  -1.02942544e+00,   8.93106729e-01,
#         -1.78448592e+00,   5.94277432e-01,   7.27236947e-01,
#          5.40512354e-01,   6.50667101e-01,  -9.24709646e-01,
#         -3.01919429e-01,  -7.54933161e-01,   4.94772414e-01,
#          2.58532433e-01,   8.85863051e-01,   1.72974049e+00,
#         -6.64768306e-01,   3.43666274e-01,   1.33436800e+00,
# ...

# %%
plt.plot(ts)

# %%
ts = ts.cumsum()

# %%
ts = pd.Series(np.random.randn(10000), index=pd.date_range('1/1/2010', periods=10000))
df = pd.DataFrame(np.random.randn(10000, 6), index=ts.index, columns=list('ABCDEF'))

# %%
df = df.cumsum()
plt.figure()
df.plot()

# %%
data = pd.read_csv('iris.csv')

# %%
plt.figure()

# %%
plt.show()

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    name
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df = pd.DataFrame(np.random.rand(4, 2))

# %%
df
# Out:
#           0         1
# 0  0.816359  0.486817
# 1  0.289711  0.462420
# 2  0.387954  0.493083
# 3  0.067932  0.564041

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
plt.plot(index=['a', 'b', 'c', 'd'], columns=['x', 'y'])
# Out:
# []

# %%
from pandas.tools.plotting import parallel_coordinates

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width       name
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
parallel_coordinates(data,'name')

# %%
from pandas.tools.plotting import andrews_curves

# %%
andrews_curves(data,'name')

# %%
from pandas.tools.plotting import radviz
radviz(data,'name')
